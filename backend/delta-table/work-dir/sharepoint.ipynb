# %%
from udl import udl
import json


tenant_name = 'pontusvisioncom'
site_name = 'FormitiXPontusVision'
list_name = 'RoPa'

# Authentication details
tenant_id = ''
app_client_id = ''
client_secret_val = ''

with open('/data/credentials.json') as f:
    data = json.load(f)
    tenant_id = data['tenant_id']
    app_client_id = data['app_client_id']
    client_secret_val = data['client_secret_val']

udlVar = udl.UDL_Sharepoint(
    spark,
    '/data',
    tenant_id,
    app_client_id,
    client_secret_val,
    tenant_name,
    site_name
)


site_id = (await udlVar.get_site_id())
print(site_id)
list_id = await udlVar.get_list_id_by_display_name(site_id, list_name)
print(list_id)
# await udlVar.process(list_name,None,None,None,None,None)
# df = await udlVar.list_data_to_dataframe(list_name)
# df.toJSON().collect()
# Out:
# 'Delta Spark version [3 2 0]; use_liquid_clustering = True'
# 24/06/25 17:44:52 WARN SimpleFunctionRegistry: The function validate_json_udf replaced a previously registered function.
# 24/06/25 17:44:52 WARN SimpleFunctionRegistry: The function anonymise_udf replaced a previously registered function.
# pontusvisioncom.sharepoint.com,46df1d00-55a1-4708-b778-60ce8cdfa73b,0ae06f7b-17ae-4674-b4db-8ad50bfbf134
# 6aa5eae9-1422-47d4-83f7-3f9e4dac0058

# %%
 # %load_ext sparksql_magic

# %%
# %%sparksql
# SELECT * FROM delta.`/data/silver/flattened/delta-parquet/RoPa_1`
# -- SELECT * FROM delta.`/data/bronze/split/delta-parquet/RoPa_1`
# Out:
# 24/05/27 10:54:11 WARN HiveConf: HiveConf of name hive.stats.jdbc.timeout does not exist
# 24/05/27 10:54:11 WARN HiveConf: HiveConf of name hive.stats.retries.wait does not exist
# 24/05/27 10:54:13 WARN ObjectStore: Version information not found in metastore. hive.metastore.schema.verification is not enabled so recording the schema version 2.3.0
# 24/05/27 10:54:13 WARN ObjectStore: setMetaStoreSchemaVersion called but recording version is disabled: version = 2.3.0, comment = Set by MetaStore UNKNOWN@172.17.0.2
# 24/05/27 10:54:13 WARN ObjectStore: Failed to get database global_temp, returning NoSuchObjectException
# 24/05/27 10:54:14 WARN ObjectStore: Failed to get database delta, returning NoSuchObjectException
# 24/05/27 10:54:19 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# only showing top 20 row(s)
# ...

# %%
spark.read.format('delta').load('/data/silver/flattened/delta-parquet/RoPa_1').toPandas()
# Out:
# 24/05/26 21:57:59 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
#                                 @odata.etag  Attachments AuthorLookupId  \
# 0    790a4b06-63c1-4845-9470-5ba0c1c5dced,5        False              9
# 1    9399827f-35dd-4862-bd0d-5f0314b3a713,6        False              9
# 2    64568fd6-dc69-4e9e-a5cd-e6ec2bdeddac,6        False              9
# 3    64568fd6-dc69-4e9e-a5cd-e6ec2bdeddac,6        False              9
# 4    2a66d570-38fa-4b86-9275-1ee1e2e3b976,5        False              9
# ..                                      ...          ...            ...
# 343  fe514dc8-9e84-49de-aba5-15bdcc067c6c,5        False              9
# 344  ec3e4c03-19b1-480d-a6c6-23f07eb2b6cf,8        False              9
# 345  ec3e4c03-19b1-480d-a6c6-23f07eb2b6cf,8        False              9
# ...
